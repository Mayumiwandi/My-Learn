# %% [markdown]
# Ini adalah Latihan Tokenization NLP

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding

# %%
tokenizer = Tokenizer(num_words= 15, oov_token='oov')

# %%
teks = ['Saya suka programming',
        'Programming sangat menyenangkan!',
        'Machine Learning berbeda dengan pemrograman konvensional',
        'Saya akan membuat sebuah project besar dalam sejarah Machine Learning']

# %%
tokenizer.fit_on_texts(teks)

# %%
sequences = tokenizer.texts_to_sequences(teks)

# %%
print(tokenizer.word_index)
# Out:
# {'oov': 1, 'saya': 2, 'programming': 3, 'machine': 4, 'learning': 5, 'suka': 6, 'sangat': 7, 'menyenangkan': 8, 'berbeda': 9, 'dengan': 10, 'pemrograman': 11, 'konvensional': 12, 'akan': 13, 'membuat': 14, 'sebuah': 15, 'project': 16, 'besar': 17, 'dalam': 18, 'sejarah': 19}

# %%
sequences_samapanjang = pad_sequences(sequences,
                                      padding='post',
                                      maxlen=10,
                                      truncating='post')

# %%
print(sequences_samapanjang)
# Out:
# [[ 2  6  3  0  0  0  0  0  0  0]
#  [ 3  7  8  0  0  0  0  0  0  0]
#  [ 4  5  9 10 11 12  0  0  0  0]
#  [ 2 13 14  1  1  1  1  1  4  5]]

# %% [markdown]
# Melakukan Emmbeding pada teks
